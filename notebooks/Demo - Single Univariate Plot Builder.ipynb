# %%
# !pip list
# Out:
# zsh:1: /Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/NielsOta/Code/univariate_plotter/venv/bin/pip: bad interpreter: /Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Code/univariate_plotter/venv/bin/python: no such file or directory
# Package                  Version
# ------------------------ ---------
# anyio                    3.7.0
# appnope                  0.1.3
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# astor                    0.8.1
# astroid                  2.15.5
# asttokens                2.2.1
# atomicwrites             1.4.1
# attrs                    23.1.0
# backcall                 0.2.0
# beautifulsoup4           4.12.2
# bleach                   6.0.0
# build                    0.10.0
# CausalInference          0.1.3
# certifi                  2023.5.7
# cffi                     1.15.1
# cfgv                     3.3.1
# charset-normalizer       3.1.0
# click                    8.1.7
# click-default-group      1.2.4
# cloup                    0.13.1
# colour                   0.1.5
# comm                     0.1.3
# contourpy                1.1.0
# cycler                   0.11.0
# Cython                   3.0.0
# debugpy                  1.6.7
# decorator                5.1.1
# defusedxml               0.7.1
# dill                     0.3.6
# distlib                  0.3.6
# docutils                 0.20.1
# exceptiongroup           1.1.1
# executing                1.2.0
# fastjsonschema           2.17.1
# filelock                 3.12.2
# fonttools                4.40.0
# formulaic                0.6.4
# fqdn                     1.5.1
# glcontext                2.4.0
# graphviz                 0.20.1
# identify                 2.5.24
# idna                     3.4
# importlib-metadata       6.7.0
# iniconfig                2.0.0
# interface-meta           1.3.0
# ipykernel                6.23.3
# ipython                  8.12.2
# ipython-genutils         0.2.0
# ipywidgets               8.0.6
# isoduration              20.11.0
# isort                    5.12.0
# isosurfaces              0.1.0
# jaraco.classes           3.2.3
# jedi                     0.18.2
# Jinja2                   3.1.2
# joblib                   1.3.2
# jsonpointer              2.4
# jsonschema               4.17.3
# jupyter                  1.0.0
# jupyter_client           8.3.0
# jupyter-console          6.6.3
# jupyter_core             5.3.1
# jupyter-events           0.6.3
# jupyter-manim            1.3
# jupyter_server           2.7.0
# jupyter_server_terminals 0.4.4
# jupyterlab-pygments      0.2.2
# jupyterlab-widgets       3.0.7
# kaleido                  0.2.1
# keyring                  24.0.1
# kiwisolver               1.4.4
# lazy-object-proxy        1.9.0
# linearmodels             5.2
# lxml                     4.9.2
# manim                    0.17.3
# manimlib                 0.2.0
# ManimPango               0.4.3
# mapbox-earcut            1.0.1
# markdown-it-py           3.0.0
# MarkupSafe               2.1.3
# matplotlib               3.5.2
# matplotlib-inline        0.1.6
# maturin                  0.15.2
# mccabe                   0.7.0
# mdurl                    0.1.2
# mistune                  3.0.1
# moderngl                 5.8.2
# moderngl-window          2.4.4
# more-itertools           9.1.0
# mpmath                   1.3.0
# multipledispatch         1.0.0
# mypy-extensions          1.0.0
# nbclassic                1.0.0
# nbclient                 0.8.0
# nbconvert                7.6.0
# nbformat                 5.9.0
# nest-asyncio             1.5.6
# networkx                 2.8.8
# nodeenv                  1.8.0
# nomkl                    0.0.3
# notebook                 6.5.4
# notebook_shim            0.2.3
# numpy                    1.22.4
# opencv-python            4.8.0.76
# overrides                7.3.1
# packaging                23.1
# pandas                   2.1.1
# pandocfilters            1.5.0
# parso                    0.8.3
# patsy                    0.5.3
# pexpect                  4.8.0
# pickleshare              0.7.5
# Pillow                   9.5.0
# pip                      23.3.1
# pkginfo                  1.9.6
# platformdirs             3.8.0
# plotly                   5.15.0
# plottah                  0.1.26
# pluggy                   1.2.0
# pre-commit               3.3.3
# progressbar              2.5
# prometheus-client        0.17.0
# prompt-toolkit           3.0.38
# psutil                   5.9.5
# ptyprocess               0.7.0
# pure-eval                0.2.2
# py                       1.11.0
# py4j                     0.10.9.5
# pyasn1                   0.5.0
# pycairo                  1.24.0
# pycparser                2.21
# pydantic                 1.10.13
# pydub                    0.25.1
# pyglet                   2.0.9
# Pygments                 2.15.1
# pyhdfe                   0.2.0
# pylint                   2.17.4
# pyobjc-core              9.2
# pyobjc-framework-Cocoa   9.2
# pyparsing                3.1.0
# pyproject_hooks          1.0.0
# pyrr                     0.10.3
# pyrsistent               0.19.3
# pyspark                  3.3.0
# pytest                   7.4.2
# python-dateutil          2.8.2
# python-dotenv            1.0.0
# python-json-logger       2.0.7
# python-pptx              0.6.21
# pytz                     2023.3
# PyYAML                   6.0
# pyzmq                    25.1.0
# qtconsole                5.4.3
# QtPy                     2.3.1
# readme-renderer          40.0
# requests                 2.31.0
# requests-toolbelt        1.0.0
# rfc3339-validator        0.1.4
# rfc3986                  2.0.0
# rfc3986-validator        0.1.1
# rich                     13.4.2
# rsa                      4.9
# rust_statespace          0.1.5
# scikit-learn             1.3.2
# scipy                    1.7.3
# screeninfo               0.8.1
# seaborn                  0.12.2
# Send2Trash               1.8.2
# setuptools               68.2.2
# setuptools-scm           7.1.0
# six                      1.16.0
# skia-pathops             0.7.4
# sklearn                  0.0.post5
# sniffio                  1.3.0
# soupsieve                2.4.1
# srt                      3.5.3
# stack-data               0.6.2
# statsmodels              0.14.0
# svgelements              1.9.6
# sympy                    1.12
# tenacity                 8.2.2
# terminado                0.17.1
# threadpoolctl            3.1.0
# tinycss2                 1.2.1
# toml                     0.10.2
# tomli                    2.0.1
# tomlkit                  0.11.8
# tornado                  6.3.2
# tqdm                     4.65.0
# traitlets                5.9.0
# twine                    4.0.2
# typing_extensions        4.6.3
# tzdata                   2023.3
# uri-template             1.3.0
# urllib3                  2.0.3
# virtualenv               20.23.1
# watchdog                 2.3.1
# wcwidth                  0.2.6
# webcolors                1.13
# webencodings             0.5.1
# websocket-client         1.6.1
# widgetsnbextension       4.0.7
# wrapt                    1.15.0
# XlsxWriter               3.1.2
# zipp                     3.15.0

# %%
# !pip show plottah
# Out:
# zsh:1: /Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/NielsOta/Code/univariate_plotter/venv/bin/pip: bad interpreter: /Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Code/univariate_plotter/venv/bin/python: no such file or directory
# Name: plottah
# Version: 0.1.26
# Summary:
# Home-page:
# Author: Niels Ota
# Author-email:
# License:
# Location: /Users/otaniels/.pyenv/versions/3.10.1/lib/python3.10/site-packages
# Requires: jupyter, numpy, pandas, plotly, pre-commit, pydantic, pylint, pytest, python-pptx, pyyaml, scikit-learn, seaborn, tqdm
# Required-by:

# %%
from plottah.colors import BCG_COLORS

import pathlib
import sys

import pandas as pd
ROOT = pathlib.Path().resolve().parent
pd.set_option('display.max_columns', None)

import plotly.io as pio
pio.renderers.default = "iframe"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/NielsOta/Code/univariate_plotter/notebooks/Demo - Single Univariate Plot Builder.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup%2CInc/Documents/NielsOta/Code/univariate_plotter/notebooks/Demo%20-%20Single%20Univariate%20Plot%20Builder.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from plottah.colors import BCG_COLORS
#       <a href='vscode-notebook-cell:/Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup%2CInc/Documents/NielsOta/Code/univariate_plotter/notebooks/Demo%20-%20Single%20Univariate%20Plot%20Builder.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import pathlib
#       <a href='vscode-notebook-cell:/Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup%2CInc/Documents/NielsOta/Code/univariate_plotter/notebooks/Demo%20-%20Single%20Univariate%20Plot%20Builder.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import sys
#
# ModuleNotFoundError: No module named 'plottah'

# %%
DATA_PATH = ROOT / 'data' / 'example_data' / 'test_sample.csv'
df_sample = pd.read_csv(DATA_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/NielsOta/Code/univariate_plotter/notebooks/Demo - Single Univariate Plot Builder.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup%2CInc/Documents/NielsOta/Code/univariate_plotter/notebooks/Demo%20-%20Single%20Univariate%20Plot%20Builder.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> DATA_PATH = ROOT / 'data' / 'example_data' / 'test_sample.csv'
#       <a href='vscode-notebook-cell:/Users/otaniels/Library/CloudStorage/OneDrive-TheBostonConsultingGroup%2CInc/Documents/NielsOta/Code/univariate_plotter/notebooks/Demo%20-%20Single%20Univariate%20Plot%20Builder.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df_sample = pd.read_csv(DATA_PATH)
#
# NameError: name 'ROOT' is not defined

# %%
from plottah.plot_builder import build_univariate_plot, build_univariate_plots

# %%
plot = build_univariate_plot(
    df = df_sample,
    feature_col = 'D_MAX_DAYS_PAST_DUE_6M_N',
    target = 'FLAG_60_DPD_366_DAYS',
    feature_type = "float",
    colors = BCG_COLORS,
    show_plot = True,
    hoverinfo="all",
    n_bins = 5,
    bins = None,
    specs = None,
)

# %%
plot = build_univariate_plot(
    df = df_sample,
    feature_col = 'A_TENURE_MONTHS_N',
    target = 'FLAG_60_DPD_366_DAYS',
    feature_type = "float",
    colors = BCG_COLORS,
    show_plot = True,
    hoverinfo="all",
    n_bins = 5,
    bins = [1, 5, 10, 20, 100],
    specs = None,
)

# %%
plot = build_univariate_plot(
    df = df_sample,
    feature_col = 'LN_LEXISNEXIS_THIN_FILE_FLAG_B',
    target = 'FLAG_60_DPD_366_DAYS',
    feature_type = "categorical",
    colors = BCG_COLORS,
    show_plot = True,
    hoverinfo="all",
    n_bins = 5,
    specs = None,
)
